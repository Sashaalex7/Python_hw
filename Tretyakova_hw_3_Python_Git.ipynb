# %% [markdown]
# Задание 1

# %%
data = [
[13, 25, 23, 34],
[45, 32, 44, 47],
[12, 33, 23, 95],
[13, 53, 34, 35],
]

# %%
def diag_sum(data):
    all_sum=0
    for i in range(len(data)):
        all_sum+=data[i][i]
    print(all_sum)

# %%
diag_sum(data)
# Out:
# 103

# %% [markdown]
# Задание 2

# %%
data1 = [1, '5', 'abc', 20, '2']
def sq_sum_x1(data1):
    sum_x=0
    for i in data1:
        try:
            int(i)
            sum_x += int(i)**2
        except ValueError:
            sum_x +=0
    return(sum_x)
print(sq_sum_x1(data1))
# Out:
# 430

# %% [markdown]
# Задание 3

# %%
import requests

# %%
def getRequest():
    r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
    return  r.json()['Valute']
    response=r.getRequest()

# %%
a=[]
b=[]
def getMax():
    for i in response['Valute']:
        a. append(i)
        b.append(response['Valute'][i]['Value'])
    return a[b.index(max(b))], max(b)
print(getMax())
# Out:
# ('DKK', 99.2808)
